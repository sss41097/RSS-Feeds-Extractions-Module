# %%
import os
import re
import time
import logging
import MySQLdb
import requests
import warnings
from google.cloud import translate
logging.basicConfig(filename='log_file.log', level=logging.DEBUG,
						format='Time: %(asctime)s, Logged At Line: %(lineno)d, %(message)s')


logging.info('Info: {}'.format("translater Script Running."))

translate_client = translate.Client.from_service_account_json('updraft-data-API-key.txt')

warnings.filterwarnings('ignore', category=MySQLdb.Warning)

#logging module used for log file creation
logging.basicConfig(filename='log_file.log', level=logging.DEBUG,
                format='Time: %(asctime)s, Logged At Line: %(lineno)d, %(message)s')

try:
    conn=MySQLdb.connect(host='localhost',user='root',passwd='')
    conn.set_character_set('utf8')
    cursor = conn.cursor()
    cursor.execute('SET NAMES utf8;')
    cursor.execute('SET CHARACTER SET utf8;')
    cursor.execute('SET character_set_connection=utf8;')
    logging.info('info:Database loaded successfully.')

except Exception as error:
    logging.critical('Error: {}'.format(error))
    logging.info('Info: {}'.format("translator Script Closed."))
    exit("error, see logs")


#load text files that contains ids of already translated articles


#fetch all english articles
cursor.execute('use main_database')
cursor.execute('select * from english_database')
entries = cursor.fetchall()		

# ### Language Codes: 
# Telugu : 'te' 
# Tamil : 'ta' 
# Kannada : 'kn' 
# Bengali : 'bn' 
# Hindi : 'hi' 

languages = {'hindi':'hi','tamil':'ta','kannada':'kn','bengali':'bn','telugu':'te'}

# %%
def new_id(id):
    if id in ids:
        return False
    else:
        return True

# %%
try:
        ids_file = open(r'C:\Users\shashank\Desktop\sql_implementation\translated_articles_ids.txt','r')
        ids = ids_file.readlines()
        ids = [id.rstrip() for id in ids]
        ids_file.close()
        logging.info('Info: {}'.format("translated articles ids extracted."))

except Exception as error:
        logging.error('Error: {}'.format(error))
        logging.info('Info: {}'.format("translator Script Closed."))
        exit("error,see logs")



k=0
for entry in entries:
    ide=entry[0]
    published_date=entry[1]
    if published_date is None:
        published_date = '0000-00-00'
    print(published_date)
    title=entry[2]
    link=entry[3]
    source=entry[4]
    summary=entry[5]
    content=entry[6]
    
    if new_id(ide):
            flag=0
            for language,code in languages.items():
                
                    print("TRANSLATION FOR ARTICLE NO.= ",k, "STARTED IN ",language.upper(),"LANGUAGE")
                    
                    while(1):

                        try:
                            translation = translate_client.translate(title,source_language='en',target_language=code)
                            translated_title = translation['translatedText']
                            print("title for article no. ",k," translated." )
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                        
                    
                    while(1):

                        try:
                            translation = translate_client.translate(summary,source_language='en',target_language=code)
                            translated_summary = translation['translatedText']
                            print("summary for article no. ",k," translated." )
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                        


                    
                    #breaking of big content text into parts
                    j=0
                    stop_count=0
                    original_content_parts=[]
                    for i in range(0,len(content)):
                        #print(text[j:i])
                        if i == len(content)-1:
                            original_content_parts.append(content[j:i+1])
                            break
                        if content[i]==".":
                            stop_count=stop_count+1
                            if stop_count%50==0:
                                original_content_parts.append(content[j:i])
                                j=i+1
                                
                                
                    print("Total original parts made for content of article no. ",k," is = ",len(original_content_parts))
                    translated_content_parts=[]
                    
                    #translating each part of content
                    for part in original_content_parts:
                        while (1):
                            try:
                                translation = translate_client.translate(part,source_language='en',target_language=code)
                                translated_content_parts.append(translation['translatedText'])
                                break
                            except:
                                print("sleeping for 10 seconds due to user limit exceed")
                                time.sleep(10)
                    print("Total translated parts made for content of article no. ",k," is = ",len(translated_content_parts))

                    if 'hindi' in language:
                        translated_content = "|".join(translated_content_parts)
                    elif 'bengali' in language:
                        translated_content = "|".join(translated_content_parts)
                    else:
                        translated_content = ".".join(translated_content_parts)
                    
                    
                    '''
                    # tester, ignore.
                    while(1):
                        try:
                            translation = translate_client.translate(content,source_language='en',target_language=code)
                            checker = translation['translatedText']
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                    print("SIZE OF TRANSLATED CONTENT IF NOT BREAKED = ",len(checker))
                    print("SIZE OF TRANSLATED CONTENT IF BREAKED = ",len(translated_content))
                    '''
                    
                    string = language + '_database'
                    try:
                        cursor.execute('use main_database')
                        query_string = 'insert ' + string + ' values (%s,%s,%s,%s,%s,%s,%s)'
                        cursor.execute(query_string,(ide,published_date,translated_title,link,source,translated_summary,translated_content))
                        print("article ",i," translated for ",language," language\n")
                    except:
                        continue
                   

            
            
            
            conn.commit()	
            print("ARTICLE NO.",k,"HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE")
            k=k+1
            
            with open(r'C:\Users\shashank\Desktop\sql_implementation\translated_articles_ids.txt','a') as f:
                f.write('{}\n'.format(ide))
            logging.info('Info: Article successfully translated with id : {}'.format(ide))
    else:
        print("article skipped for translation already translated")
# Out:
# 2012-06-25
# article skipped for translation already translated
# 2003-02-01
# article skipped for translation already translated
# 2017-09-25
# article skipped for translation already translated
# 2011-05-16
# article skipped for translation already translated
# 2016-03-08
# article skipped for translation already translated
# 2011-03-31
# article skipped for translation already translated
# 2007-01-20
# article skipped for translation already translated
# 2004-12-01
# article skipped for translation already translated
# 2010-12-06
# article skipped for translation already translated
# 2016-12-12
# article skipped for translation already translated
# 2010-01-20
# article skipped for translation already translated
# 2010-12-02
# article skipped for translation already translated
# 2008-01-29
# article skipped for translation already translated
# 2013-04-01
# article skipped for translation already translated
# 2012-09-19
# article skipped for translation already translated
# 2015-01-27
# article skipped for translation already translated
# 2008-03-04
# article skipped for translation already translated
# 2012-07-04
# article skipped for translation already translated
# 2013-06-03
# article skipped for translation already translated
# 2010-02-25
# article skipped for translation already translated
# 2003-08-01
# article skipped for translation already translated
# 2018-11-05
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2009-03-03
# article skipped for translation already translated
# 2003-07-01
# article skipped for translation already translated
# 2017-11-27
# article skipped for translation already translated
# 2010-05-20
# article skipped for translation already translated
# 2011-02-04
# article skipped for translation already translated
# 2000-02-25
# article skipped for translation already translated
# 2013-04-09
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2013-07-08
# article skipped for translation already translated
# 0000-00-00
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2005-10-22
# article skipped for translation already translated
# 2013-06-12
# article skipped for translation already translated
# 2013-03-14
# article skipped for translation already translated
# 2004-02-01
# article skipped for translation already translated
# 2010-11-23
# article skipped for translation already translated
# 2008-05-30
# article skipped for translation already translated
# 2013-10-24
# article skipped for translation already translated
# 2017-05-10
# article skipped for translation already translated
# 2007-02-20
# article skipped for translation already translated
# 2003-05-01
# article skipped for translation already translated
# 2018-06-26
# article skipped for translation already translated
# 2016-01-27
# article skipped for translation already translated
# 2016-07-11
# article skipped for translation already translated
# 2006-03-30
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2016-07-04
# article skipped for translation already translated
# 2014-06-13
# article skipped for translation already translated
# 2015-10-05
# article skipped for translation already translated
# 2003-06-01
# article skipped for translation already translated
# 2006-01-18
# article skipped for translation already translated
# 2009-04-12
# article skipped for translation already translated
# 2017-02-28
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2011-12-08
# article skipped for translation already translated
# 2013-06-25
# article skipped for translation already translated
# 2015-07-16
# article skipped for translation already translated
# 2009-11-06
# article skipped for translation already translated
# 2017-01-10
# article skipped for translation already translated
# 2015-03-27
# article skipped for translation already translated
# 2012-02-23
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2006-12-28
# article skipped for translation already translated
# 2007-04-12
# article skipped for translation already translated
# 2014-09-04
# article skipped for translation already translated
# 2005-01-20
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2018-08-23
# article skipped for translation already translated
# 2018-10-24
# article skipped for translation already translated
# 2003-05-01
# article skipped for translation already translated
# 2014-08-18
# article skipped for translation already translated
# 2014-11-04
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2010-02-03
# article skipped for translation already translated
# 2018-07-03
# article skipped for translation already translated
# 2003-01-01
# article skipped for translation already translated
# 2006-04-04
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2015-02-17
# article skipped for translation already translated
# 2013-06-10
# article skipped for translation already translated
# 2018-07-03
# article skipped for translation already translated
# 2017-07-04
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2013-08-27
# article skipped for translation already translated
# 2018-12-24
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2010-06-29
# article skipped for translation already translated
# 2008-05-21
# article skipped for translation already translated
# 2018-10-03
# article skipped for translation already translated
# 2013-05-02
# article skipped for translation already translated
# 2010-08-15
# article skipped for translation already translated
# 2013-11-03
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2015-05-01
# article skipped for translation already translated
# 2013-08-28
# article skipped for translation already translated
# 2017-05-11
# article skipped for translation already translated
# 2015-06-12
# article skipped for translation already translated
# 2011-12-29
# article skipped for translation already translated
# 2018-04-16
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2007-07-30
# article skipped for translation already translated
# 2010-11-11
# article skipped for translation already translated
# 2018-05-04
# article skipped for translation already translated
# 2003-12-01
# article skipped for translation already translated
# 2009-09-11
# article skipped for translation already translated
# 2011-02-04
# article skipped for translation already translated
# 2005-05-30
# article skipped for translation already translated
# 2000-02-25
# article skipped for translation already translated
# 2017-04-07
# article skipped for translation already translated
# 2000-02-25
# article skipped for translation already translated
# 2017-10-04
# article skipped for translation already translated
# 2008-05-14
# article skipped for translation already translated
# 2018-10-29
# article skipped for translation already translated
# 2018-11-01
# article skipped for translation already translated
# 2018-05-17
# article skipped for translation already translated
# 2013-05-31
# article skipped for translation already translated
# 2018-11-13
# article skipped for translation already translated
# 2019-01-02
# article skipped for translation already translated
# 2007-01-06
# article skipped for translation already translated
# 2015-10-14
# article skipped for translation already translated
# 2000-05-11
# article skipped for translation already translated
# 2015-08-14
# article skipped for translation already translated
# 2016-03-11
# article skipped for translation already translated
# 2014-11-30
# article skipped for translation already translated
# 2018-07-03
# article skipped for translation already translated
# 2011-03-17
# article skipped for translation already translated
# 2008-12-14
# article skipped for translation already translated
# 2018-04-19
# article skipped for translation already translated
# 2009-12-14
# article skipped for translation already translated
# 2009-07-24
# article skipped for translation already translated
# 2006-03-11
# article skipped for translation already translated
# 2013-01-18
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  HINDI LANGUAGE
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000002827CC5D400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='oauth2.googleapis.com', port=443): Max retries exceeded with url: /token (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002827CC5D400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\google\auth\transport\requests.py in __call__(self, url, method, body, headers, timeout, **kwargs)
#     119                 method, url, data=body, headers=headers, timeout=timeout,
# --> 120                 **kwargs)
#     121             return _Response(response)
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#
# ConnectionError: HTTPSConnectionPool(host='oauth2.googleapis.com', port=443): Max retries exceeded with url: /token (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002827CC5D400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# The above exception was the direct cause of the following exception:
#
# TransportError                            Traceback (most recent call last)
# <ipython-input-3-92b304be64f8> in <module>()
#      36                         try:
# ---> 37                             translation = translate_client.translate(title,source_language='en',target_language=code)
#      38                             translated_title = translation['translatedText']
#
# ~\Anaconda3\lib\site-packages\google\cloud\translate_v2\client.py in translate(self, values, target_language, format_, source_language, customization_ids, model)
#     238
# --> 239         response = self._connection.api_request(method="POST", path="", data=data)
#     240
#
# ~\Anaconda3\lib\site-packages\google\cloud\_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     314             headers=headers,
# --> 315             target_object=_target_object,
#     316         )
#
# ~\Anaconda3\lib\site-packages\google\cloud\_http.py in _make_request(self, method, url, data, content_type, headers, target_object)
#     191
# --> 192         return self._do_request(method, url, headers, data, target_object)
#     193
#
# ~\Anaconda3\lib\site-packages\google\cloud\_http.py in _do_request(self, method, url, headers, data, target_object)
#     220         """
# --> 221         return self.http.request(url=url, method=method, headers=headers, data=data)
#     222
#
# ~\Anaconda3\lib\site-packages\google\auth\transport\requests.py in request(self, method, url, data, headers, **kwargs)
#     197         self.credentials.before_request(
# --> 198             self._auth_request, method, url, request_headers)
#     199
#
# ~\Anaconda3\lib\site-packages\google\auth\credentials.py in before_request(self, request, method, url, headers)
#     121         if not self.valid:
# --> 122             self.refresh(request)
#     123         self.apply(headers)
#
# ~\Anaconda3\lib\site-packages\google\oauth2\service_account.py in refresh(self, request)
#     321         access_token, expiry, _ = _client.jwt_grant(
# --> 322             request, self._token_uri, assertion)
#     323         self.token = access_token
#
# ~\Anaconda3\lib\site-packages\google\oauth2\_client.py in jwt_grant(request, token_uri, assertion)
#     144
# --> 145     response_data = _token_endpoint_request(request, token_uri, body)
#     146
#
# ~\Anaconda3\lib\site-packages\google\oauth2\_client.py in _token_endpoint_request(request, token_uri, body)
#     105     response = request(
# --> 106         method='POST', url=token_uri, headers=headers, body=body)
#     107
#
# ~\Anaconda3\lib\site-packages\google\auth\transport\requests.py in __call__(self, url, method, body, headers, timeout, **kwargs)
#     123             new_exc = exceptions.TransportError(caught_exc)
# --> 124             six.raise_from(new_exc, caught_exc)
#     125
#
# ~\Anaconda3\lib\site-packages\six.py in raise_from(value, from_value)
#
# TransportError: HTTPSConnectionPool(host='oauth2.googleapis.com', port=443): Max retries exceeded with url: /token (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002827CC5D400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-92b304be64f8> in <module>()
#      41                         except:
#      42                             print("sleeping for 10 seconds due to user limit exceed")
# ---> 43                             time.sleep(10)
#      44
#      45
#
# KeyboardInterrupt:
